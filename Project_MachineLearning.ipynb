# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/TaiLieuCuaToi'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/TaiLieuCuaToi

# %%
#Libs for data manupulations
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Tổng quan về tập dữ liệu

# %%
dataset = pd.read_csv('water_potability.csv')
dataset=pd.DataFrame(dataset)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram
dataset.hist(figsize=(15, 10))
plt.show()

# Biểu đồ hộp
plt.figure(figsize=(15, 10))
sns.boxplot(data=dataset)
plt.xticks(rotation=90)
plt.show()

# Biểu đồ phân bố theo thuộc tính Potability
plt.figure(figsize=(15, 10))
sns.countplot(data=dataset, x='Potability')
plt.show()

# %%
dataset.tail(40)
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 3236   4.767472  256.449917  48007.868134     5.773180         NaN
# 3237   9.609834  227.366949  22690.045871     5.385440  314.317481
# 3238   9.186453  169.119805  27055.696261     7.442480         NaN
# 3239   9.960690  169.925248  15835.122818     7.143907  301.777253
# 3240   6.102307  205.999038  23406.859160     8.061864         NaN
# 3241   6.792655  241.724453   9094.313300     6.435809  338.521176
# 3242   5.910540  241.140746  25721.833866     4.806759  385.887468
# 3243   6.125810  241.443535   8810.895810     5.740321  369.022715
# 3244   5.836105  277.065713  17711.487774     3.458192  400.167599
# 3245        NaN  188.536608  24711.414927     7.129520         NaN
# 3246  10.667364  173.381945  28912.202201     7.071294  276.634391
# 3247   8.628301  185.926723  31548.006464     7.079462         NaN
# 3248   6.260111  211.594112  18577.623969     7.154891  340.792574
# ...

# %%
dataset.columns.tolist()
# Out:
# ['ph',
#  'Hardness',
#  'Solids',
#  'Chloramines',
#  'Sulfate',
#  'Conductivity',
#  'Organic_carbon',
#  'Trihalomethanes',
#  'Turbidity',
#  'Potability']

# %%
# Tổng số hàng và cột trong dataset
dataset.shape
# Out:
# (3276, 10)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numerical_features = dataset.select_dtypes(include='float64')

sns.pairplot(numerical_features)
plt.suptitle('Scatter Plot Matrix of Numerical Features', y=1.02)
plt.show()

# %%
dataset.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %% [markdown]
# Làm sạch dữ liệu

# %%
dataset.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# Sulfate            781
# ph                 491
# Trihalomethanes    162
# Hardness             0
# Solids               0
# Chloramines          0
# Conductivity         0
# Organic_carbon       0
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# Tìm feature giá trị là null
null_features=dataset.columns[dataset.isnull().any()].tolist()
print(null_features)
# Tìm số records có tất cả feature là null
null_records = dataset[null_features].isnull().all(axis=1).sum()
# Out:
# ['ph', 'Sulfate', 'Trihalomethanes']

# %%
# Xóa null record khỏi dataset
filtered_dataset = dataset.dropna(how='all', subset=null_features)
print(len(filtered_dataset))
# Out:
# 3267

# %%
null_counts_per_record = dataset.isnull().sum(axis=1)

null_features_dict = {}
for count in null_counts_per_record:
    if count in null_features_dict:
        null_features_dict[count] += 1
    else:
        null_features_dict[count] = 1

print(null_features_dict)
plt.bar(null_features_dict.keys(), null_features_dict.values())
plt.xlabel('Number of Null Features')
plt.ylabel('No. of records')
plt.title('Frequency Distribution of Null Features per Record')
plt.show()
# Out:
# {1: 1105, 0: 2011, 2: 151, 3: 9}

# %%
filtered_dataset.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# Sulfate            772
# ph                 482
# Trihalomethanes    153
# Hardness             0
# Solids               0
# Chloramines          0
# Conductivity         0
# Organic_carbon       0
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# Filter rows with only null values
filtered_null_features=dataset.columns[dataset.isnull().any()].tolist()
print(filtered_null_features)
# Out:
# ['ph', 'Sulfate', 'Trihalomethanes']

# %%
from sklearn.impute import KNNImputer
total_rows = len(filtered_dataset)
desired_neighbors = int(0.20 * total_rows)
imputer = KNNImputer(n_neighbors=desired_neighbors)
print(total_rows, desired_neighbors)
# Out:
# 3267 653

# %%
for features in filtered_null_features:
    filtered_dataset[features] = imputer.fit_transform(filtered_dataset[[features]])

filtered_dataset
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
filtered_dataset.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
filtered_dataset.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3267.000000  3267.000000   3267.000000  3267.000000  3267.000000
# mean      7.080795   196.366063  22013.423893     7.123074   333.775777
# std       1.471980    32.893960   8760.888319     1.583597    36.192376
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277117   176.847379  15665.106976     6.128488   316.994734
# 50%       7.080795   196.952875  20965.478309     7.130437   333.775777
# 75%       7.872617   216.660337  27334.162293     8.115043   350.416395
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3267.000000     3267.000000      3267.000000  3267.000000  3267.000000
# mean     426.144283       14.288057        66.396293     3.966987     0.390878
# std       80.787862        3.308664        15.791595     0.780835     0.488022
# ...

# %%
from scipy.stats import norm

for features in numerical_features:
    mean_value = filtered_dataset[features].mean()
    min_value = filtered_dataset[features].min()
    max_value = filtered_dataset[features].max()

    x = np.arange(min_value - 10, max_value + 10, 0.001)

    y = norm.pdf(x, mean_value, np.std([min_value, max_value]))

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, color='blue', label='Normal Distribution')

    plt.fill_between(x, y, where=(x >= mean_value - np.std([min_value, max_value])) & (x <= mean_value + np.std([min_value, max_value])),
                 color='lightblue', alpha=0.5, label='1 Std Dev')

    plt.axvline(x=mean_value, color='orange', linestyle='--', label='Mean')

    plt.xlabel('Feature Value')
    plt.ylabel('Probability Density')
    plt.title(f'Bell-Shaped Curve (Normal Distribution) for: {features}')
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
potability_distribution = filtered_dataset['Potability'].value_counts().reset_index()
potability_distribution.columns = ['Potability', 'Count']
potability_distribution['Potability'] = potability_distribution['Potability'].map({0: 'Non-potable', 1: 'Potable'})

explode = [ 0, 0.13]
plt.pie(potability_distribution["Count"], labels=potability_distribution["Potability"],autopct='%1.1f%%', explode=explode)
plt.show()

# %% [markdown]
# Khởi tạo các mô hình

# %%
# !pip install imbalanced-learn

# %%
import pandas as pd
from imblearn.over_sampling import RandomOverSampler

# Giả định rằng `filtered_dataset` đã được chuẩn bị và bạn đã chia thành X và y
X = filtered_dataset.drop(columns=['Potability'])
y = filtered_dataset['Potability']

# Tạo một đối tượng RandomOverSampler
ros = RandomOverSampler(random_state=42)

# Áp dụng oversampling để cân bằng các lớp trong y
X_resampled, y_resampled = ros.fit_resample(X, y)

# Kiểm tra lại số lượng mẫu sau khi oversampling
print("Số lượng mẫu trước khi cân bằng:")
print(y.value_counts())

print("Số lượng mẫu sau khi cân bằng:")
print(y_resampled.value_counts())
# Out:
# Số lượng mẫu trước khi cân bằng:
# Potability
# 0    1990
# 1    1277
# Name: count, dtype: int64
# Số lượng mẫu sau khi cân bằng:
# Potability
# 0    1990
# 1    1990
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(ax=axes[0], x=y)
axes[0].set_title('Trước khi cân bằng')
axes[0].set_xlabel('Potability')
axes[0].set_ylabel('Số lượng mẫu')

# Biểu đồ sau khi cân bằng
sns.countplot(ax=axes[1], x=y_resampled)
axes[1].set_title('Sau khi cân bằng')
axes[1].set_xlabel('Potability')
axes[1].set_ylabel('Số lượng mẫu')

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.model_selection import train_test_split

models = {
    'Random Forest Classifier': RandomForestClassifier(100),
    'Decision Tree': DecisionTreeClassifier(),
    'Neural Network': MLPClassifier()
}

X = filtered_dataset.drop(columns=['Potability'])
y = filtered_dataset['Potability']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Data split into train and test sets (80% train, 20% test)")

print("\n")

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

print("===============================================")
print("======= Model Training and Evaluation =========")
print("===============================================")

results = []
# Out:
# Data split into train and test sets (80% train, 20% test)
#
#
# ...
# ======= Model Training and Evaluation =========
# ...

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

models = {
    'Random Forest Classifier': RandomForestClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Neural Network': MLPClassifier(max_iter=1000)
}

param_grids = {
    'Random Forest Classifier': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'Decision Tree': {
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'Neural Network': {
        'hidden_layer_sizes': [(50,), (100,), (50, 50)],
        'activation': ['tanh', 'relu'],
        'solver': ['sgd', 'adam'],
        'alpha': [0.0001, 0.001, 0.01],
        'learning_rate': ['constant', 'adaptive']
    }
}

X = filtered_dataset.drop(columns=['Potability'])
y = filtered_dataset['Potability']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Data split into train and test sets (70% train, 30% test)")

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

print("===============================================")
print("======= Model Training and Evaluation =========")
print("===============================================")

def perform_grid_search(model, param_grid, x_train, y_train):
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2, scoring='accuracy')
    grid_search.fit(x_train, y_train)
    return grid_search.best_estimator_

best_models = {}

for model_name, model in models.items():
    print(f"Performing Grid Search for {model_name}")
    best_model = perform_grid_search(model, param_grids[model_name], x_train_scaled, y_train)
    best_models[model_name] = best_model
    print(f"Best parameters for {model_name}: {best_model.get_params()}")

results = []
for model_name, model in best_models.items():
    y_pred = model.predict(x_test_scaled)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    results.append({
        'Model': model_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    })

results_df = pd.DataFrame(results)
print(results_df)
# Out:
# Data split into train and test sets (70% train, 30% test)
# ...
# ======= Model Training and Evaluation =========
# ...
# Performing Grid Search for Random Forest Classifier
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best parameters for Random Forest Classifier: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 200, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Performing Grid Search for Decision Tree
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# ...

# %%
pip install imbalanced-learn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import numpy as np


X = X_resampled
y = y_resampled

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Data split into train and test sets (70% train, 30% test)")

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

models = {
    'Random Forest Classifier': RandomForestClassifier(max_depth=20, min_samples_split=10, n_estimators=200),
    'Decision Tree': DecisionTreeClassifier(max_depth=10, min_samples_leaf=1, min_samples_split=5),
    'Neural Network': MLPClassifier(max_iter=1000, hidden_layer_sizes=(100,), learning_rate='adaptive', alpha=0.01, activation='relu', solver='adam')
}

results = []

for model_name, model in models.items():
    print(f"Training {model_name}...")
    model.fit(x_train_scaled, y_train)

    y_pred = model.predict(x_test_scaled)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results.append({
        'Model': model_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    })

results_df = pd.DataFrame(results)

fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.2
index = np.arange(len(results_df['Model']))

bar1 = plt.bar(index, results_df['Accuracy'], bar_width, label='Accuracy')
bar2 = plt.bar(index + bar_width, results_df['Precision'], bar_width, label='Precision')
bar3 = plt.bar(index + 2 * bar_width, results_df['Recall'], bar_width, label='Recall')
bar4 = plt.bar(index + 3 * bar_width, results_df['F1 Score'], bar_width, label='F1 Score')

plt.xlabel('Model')
plt.ylabel('Scores')
plt.title('Comparison of Model Performance')
plt.xticks(index + bar_width, results_df['Model'])
plt.legend()

plt.show()

table = PrettyTable()
table.field_names = ["Model", "Accuracy", "Precision", "Recall", "F1 Score"]

for result in results:
    table.add_row([
        result['Model'],
        round(result['Accuracy'], 2),
        round(result['Precision'], 2),
        round(result['Recall'], 2),
        round(result['F1 Score'], 2)
    ])

# Hiển thị bảng
print(table)
# Out:
# Data split into train and test sets (70% train, 30% test)
# Training Random Forest Classifier...
# Training Decision Tree...
# Training Neural Network...
# +--------------------------+----------+-----------+--------+----------+
# |          Model           | Accuracy | Precision | Recall | F1 Score |
# +--------------------------+----------+-----------+--------+----------+
# | Random Forest Classifier |   0.75   |    0.77   |  0.72  |   0.74   |
# |      Decision Tree       |   0.62   |    0.66   |  0.52  |   0.58   |
# |      Neural Network      |   0.67   |    0.68   |  0.66  |   0.67   |
# +--------------------------+----------+-----------+--------+----------+
# +--------------------------+----------+-----------+--------+----------+
# |          Model           | Accuracy | Precision | Recall | F1 Score |
# +--------------------------+----------+-----------+--------+----------+
# | Random Forest Classifier |   0.75   |    0.77   |  0.72  |   0.74   |
# ...
